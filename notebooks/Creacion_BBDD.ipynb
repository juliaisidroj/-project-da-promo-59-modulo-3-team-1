# %%
# Tratamiento de datos
import pandas as pd
import numpy as np
# Para cargar un data en mysql
# Una librería que te permite conectar Python con una base de datos MySQL.
import mysql.connector
from mysql.connector import errorcode
# Configuración
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
# Gestión de los warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Cargar los archivos
df_abc = pd.read_csv('../files/hr_clean.csv', index_col=0)

# %%
df_abc.shape
# Out:
# (1474, 33)

# %%
import mysql.connector

def crear_base_de_datos():
    try:
        # 1. Conexión al servidor (ajusta el user y password a los tuyos)
        conexion = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mew33uga" 
        )
        
        cursor = conexion.cursor()
        
        # 2. Crear la base de datos si no existe
        cursor.execute("CREATE DATABASE IF NOT EXISTS ABC_Corporation")
        print("Base de datos 'ABC_Corporation' creada con éxito.")
        
      
    except mysql.connector.Error as err:
        print(f"Error: {err}")

crear_base_de_datos()
# Out:
# Base de datos 'ABC_Corporation' creada con éxito.

# %%
query_insert = """
INSERT INTO datos_abc ('employee_number','age', 'attrition', 'business_travel', 'daily_rate', 'department',
       'distance_from_home', 'education', 'education_field', 'employee_count',
       'environment_satisfaction', 'gender', 'hourly_rate',
       'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
       'marital_status', 'monthly_income', 'monthly_rate',
       'num_companies_worked', 'over_time', 'percent_salary_hike',
       'performance_rating', 'relationship_satisfaction', 'stock_option_level',
       'total_working_years', 'training_times_last_year', 'work_life_balance',
       'years_at_company', 'years_in_current_role',
       'years_since_last_promotion', 'years_with_curr_manager')
VALUES (%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s)
"""
cursor.executemany(query_insert, datos_abc)
cnx.commit()
print(f"{cursor.rowcount} registros insertados")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 14
#       1 query_insert = """
#       2 INSERT INTO datos_abc ('employee_number','age', 'attrition', 'business_travel', 'daily_rate', 'department',
#       3        'distance_from_home', 'education', 'education_field', 'employee_count',
#    (...)     12 VALUES (%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s, %s, %s, %s,%s, %s, %s)
#      13 """
# ---> 14 cursor.executemany(query_insert, datos_abc)
#      15 cnx.commit()
#      16 print(f"{cursor.rowcount} registros insertados")
#
# NameError: name 'cursor' is not defined
