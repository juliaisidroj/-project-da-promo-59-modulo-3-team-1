# %%
# Tratamiento de datos
import pandas as pd
import numpy as np
# Para cargar un data en mysql
# Una librería que te permite conectar Python con una base de datos MySQL.
import mysql.connector
from mysql.connector import errorcode
# Configuración
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
# Gestión de los warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Cargar los archivos
df_abc = pd.read_csv('../files/hr_clean.csv', index_col=0)

# %%
df_abc.shape
# Out:
# (1474, 33)

# %%
import mysql.connector

def crear_base_de_datos():
    try:
        # 1. Conexión al servidor (ajusta el user y password a los tuyos)
        conexion = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mew33uga" 
        )
        
        cursor = conexion.cursor()
        
        # 2. Crear la base de datos si no existe
        cursor.execute("CREATE DATABASE IF NOT EXISTS ABC_Corporation")
        print("Base de datos 'ABC_Corporation' creada con éxito.")
        
      
    except mysql.connector.Error as err:
        print(f"Error: {err}")

crear_base_de_datos()
# Out:
# Base de datos 'ABC_Corporation' creada con éxito.

# %%
# 1. Conexión al servidor (ajusta el user y password a los tuyos)
try:
        conexion = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mew33uga" 
        )
        
        cursor = conexion.cursor()
except mysql.connector.Error as err:
        print(f"Error: {err}")

# %%
# 2. Preparamos los datos del DataFrame (convertir a lista de tuplas)
# Asumiendo que tu df se llama df_abc como en la celda 10
datos_para_insertar = list(df_abc.itertuples(index=False, name=None))

# %%
query_insert = """
INSERT INTO empleados ('age', 'gender', 'marital_status', 'education', 'education_field', 'distance_from_home', 'employee_count')
VALUES (%s, %s, %s, %s, %s, %s,%s)
"""
cursor.executemany(query_insert, datos_para_insertar)
cnx.commit()
print(f"{cursor.rowcount} registros insertados")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[24], line 8
#       1 datos_para_insertar = list(df_abc.itertuples(index=False, name=None))
#       4 query_insert = """
#       5 INSERT INTO empleados ('age', 'gender', 'marital_status', 'education', 'education_field', 'distance_from_home', 'employee_count')
#       6 VALUES (%s, %s, %s, %s, %s, %s,%s)
#       7 """
# ----> 8 cursor.executemany(query_insert, datos_para_insertar)
#       9 cnx.commit()
#      10 print(f"{cursor.rowcount} registros insertados")
#
# File c:\Users\xela_\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\cursor_cext.py:470, in CMySQLCursor.executemany(self, operation, seq_params)
#     468     self._rowcount = 0
#     469     return None
# --> 470 stmt = self._batch_insert(operation, seq_params)
#     471 if stmt is not None:
#     472     self._executed = stmt
#
# File c:\Users\xela_\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\cursor_cext.py:424, in CMySQLCursor._batch_insert(self, operation, seq_params)
#     422     raise ProgrammingError(str(err)) from err
#     423 except Exception as err:
# --> 424     raise InterfaceError(f"Failed executing the operation; {err}") from None
#
# InterfaceError: Failed executing the operation; Not all parameters were used in the SQL statement
